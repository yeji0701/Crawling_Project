# %%
import pandas as pd

# %%
df = pd.read_csv('./datas/final2019.csv', index_col=[0])
df.tail()
# Out:
#          Artist Genre                                               Link  \
# 4267        아이유  록/메탈  https://www.melon.com/song/detail.htm?songId=3...
# 4268        MC몽  랩/힙합  https://www.melon.com/song/detail.htm?songId=3...
# 4269  ITZY (있지)    댄스  https://www.melon.com/song/detail.htm?songId=3...
# 4270  Lil tachi  랩/힙합  https://www.melon.com/song/detail.htm?songId=3...
# 4271        홍진영  성인가요  https://www.melon.com/song/detail.htm?songId=3...
#
#                     Title  Year
# 4267             Blueming  2019
# 4268  인기 (Feat. 송가인, 챈슬러)  2019
# 4269                  ICY  2019
# 4270       눈 (Prod. 기리보이)  2019
# 4271                오늘 밤에  2019

# %%
# 모듈 생성

# %%
# !mkdir -p song
# !touch song/details.py
# !touch song/genre.py

# %%
# !tree song
# Out:
# song
# ├── details.py
# └── genre.py
#
# 0 directories, 2 files

# %%
# %%writefile song/details.py

import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

def song_details(year):

        url = "https://www.melon.com/chart/age/list.htm?idx=1&chartType=YE&chartGenre=KPOP&chartDate={}&moved=Y".format(year)
        headers = {
            "User-Agent" : UserAgent().chrome
        }
        response = requests.get(url, headers=headers)
        dom = BeautifulSoup(response.text, 'html.parser')
        elements = dom.select("#frm > table > tbody tr")
        
        datas = []
        for element in elements:
            data = {
                "Title" : element.select_one('a > .odd_span').text.split('상')[0].strip(),
                "Artist" : element.select_one('div > .fc_mgray').text,
                "Year" : year,
                "Link" : 'https://www.melon.com/song/detail.htm?songId=' + element.select_one('td > div > input').get('value')
            }
            datas.append(data)
    
        return datas
# Out:
# Overwriting song/details.py

# %%
# %%writefile song/genre.py

import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

def get_genre(link):
    headers = {"User-Agent" : UserAgent().chrome}
    response = requests.get(link, headers=headers)
    dom = BeautifulSoup(response.content, 'html.parser')
    
    return dom.select_one('div.entry > div.meta > dl > dd:nth-child(6)').text
# Out:
# Overwriting song/genre.py

# %%
import song.details as song_details

# %%
d = song_details.song_details(1964)
df1 = pd.DataFrame(d)

# %%
df1.tail()
# Out:
#    Artist                                               Link       Title  Year
# 17    남일해  https://www.melon.com/song/detail.htm?songId=1...         이국땅  1964
# 18    위키리  https://www.melon.com/song/detail.htm?songId=1...  저녁 한때 목장풍경  1964
# 19    최희준  https://www.melon.com/song/detail.htm?songId=1...      진고개 신사  1964
# 20    남일해  https://www.melon.com/song/detail.htm?songId=1...    첫사랑 마도로스  1964
# 21    최양숙  https://www.melon.com/song/detail.htm?songId=8...     황혼의 에레지  1964

# %%
import song.genre as get_genre

# %%
df1['Genre'] = df1['Link'].apply(get_genre.get_genre)

# %%
df1
# Out:
#     Artist                                               Link  \
# 0      금호동  https://www.melon.com/song/detail.htm?songId=4...
# 1      최숙자  https://www.melon.com/song/detail.htm?songId=1...
# 2      이미자  https://www.melon.com/song/detail.htm?songId=1...
# 3      이미자  https://www.melon.com/song/detail.htm?songId=1...
# 4       현미  https://www.melon.com/song/detail.htm?songId=1...
# 5      백야성  https://www.melon.com/song/detail.htm?songId=4...
# 6      최희준  https://www.melon.com/song/detail.htm?songId=1...
# 7      권혜경  https://www.melon.com/song/detail.htm?songId=5...
# 8      박재란  https://www.melon.com/song/detail.htm?songId=3...
# 9       현미  https://www.melon.com/song/detail.htm?songId=1...
# 10   Add 4  https://www.melon.com/song/detail.htm?songId=2...
# 11     남일해  https://www.melon.com/song/detail.htm?songId=4...
# 12     박재란  https://www.melon.com/song/detail.htm?songId=1...
# 13     고봉산  https://www.melon.com/song/detail.htm?songId=9...
# ...

# %%
# mongodb에 데이터 올리기

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://dss:dss@3.35.112.78:27017')
client
# Out:
# MongoClient('3.35.112.78', 27017)

# %%
db = client.melon_chart
collection = db.song_list

# %%
song = pd.read_csv('./datas/final2019(rev).csv', index_col=[0])
song.tail()
# Out:
#          Artist Genre                Title  Year
# 4267        아이유  록/메탈             Blueming  2019
# 4268        MC몽  랩/힙합  인기 (Feat. 송가인, 챈슬러)  2019
# 4269  ITZY (있지)    댄스                  ICY  2019
# 4270  Lil tachi  랩/힙합       눈 (Prod. 기리보이)  2019
# 4271        홍진영  성인가요                오늘 밤에  2019

# %%
song = song.to_dict('records')
song
# Out:
# [{'Artist': '금호동', 'Genre': '성인가요', 'Title': '내일또 만납시다', 'Year': 1964},
#  {'Artist': '최숙자', 'Genre': '성인가요', 'Title': '눈물의 연평도', 'Year': 1964},
#  {'Artist': '이미자', 'Genre': '성인가요', 'Title': '님이라 부르리까', 'Year': 1964},
#  {'Artist': '이미자', 'Genre': '성인가요', 'Title': '동백아가씨', 'Year': 1964},
#  {'Artist': '현미', 'Genre': '성인가요', 'Title': '떠날때는 말없이', 'Year': 1964},
#  {'Artist': '백야성', 'Genre': '성인가요', 'Title': '마도로스 부기', 'Year': 1964},
#  {'Artist': '최희준', 'Genre': '성인가요', 'Title': '맨발의 청춘', 'Year': 1964},
#  {'Artist': '권혜경', 'Genre': '성인가요', 'Title': '물새우는 해변', 'Year': 1964},
#  {'Artist': '박재란', 'Genre': '성인가요', 'Title': '밀짚모자 목장아가씨', 'Year': 1964},
#  {'Artist': '현미', 'Genre': '성인가요', 'Title': '보고싶은 얼굴', 'Year': 1964},
#  {'Artist': 'Add 4',
#   'Genre': '록/메탈',
#   'Title': '빗속의 여인 (1964년작)',
#   'Year': 1964},
#  {'Artist': '남일해', 'Genre': '성인가요', 'Title': '빨간구두 아가씨', 'Year': 1964},
#  {'Artist': '박재란', 'Genre': '성인가요', 'Title': '소쩍새 우는 마을', 'Year': 1964},
# ...

# %%
collection.insert(song)
# Out:
# [ObjectId('5fc0d294322083083e14b7d2'),
#  ObjectId('5fc0d294322083083e14b7d3'),
#  ObjectId('5fc0d294322083083e14b7d4'),
#  ObjectId('5fc0d294322083083e14b7d5'),
#  ObjectId('5fc0d294322083083e14b7d6'),
#  ObjectId('5fc0d294322083083e14b7d7'),
#  ObjectId('5fc0d294322083083e14b7d8'),
#  ObjectId('5fc0d294322083083e14b7d9'),
#  ObjectId('5fc0d294322083083e14b7da'),
#  ObjectId('5fc0d294322083083e14b7db'),
#  ObjectId('5fc0d294322083083e14b7dc'),
#  ObjectId('5fc0d294322083083e14b7dd'),
#  ObjectId('5fc0d294322083083e14b7de'),
#  ObjectId('5fc0d294322083083e14b7df'),
#  ObjectId('5fc0d294322083083e14b7e0'),
#  ObjectId('5fc0d294322083083e14b7e1'),
#  ObjectId('5fc0d294322083083e14b7e2'),
#  ObjectId('5fc0d294322083083e14b7e3'),
#  ObjectId('5fc0d294322083083e14b7e4'),
#  ObjectId('5fc0d294322083083e14b7e5'),
#  ObjectId('5fc0d294322083083e14b7e6'),
#  ObjectId('5fc0d294322083083e14b7e7'),
#  ObjectId('5fc0d294322083083e14b7e8'),
#  ObjectId('5fc0d294322083083e14b7e9'),
# ...

# %%
collection.drop()
