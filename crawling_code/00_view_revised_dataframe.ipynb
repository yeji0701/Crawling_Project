# %%
import pandas as pd

# %%
### first version of data (without lyrics and genre not regrouped)

# %%
df1 = pd.read_csv('./datas/final2019.csv', index_col=[0])
df1
# Out:
#             Artist         Genre  \
# 0              금호동          성인가요
# 1              최숙자          성인가요
# 2              이미자          성인가요
# 3              이미자          성인가요
# 4               현미          성인가요
# 5              백야성          성인가요
# 6              최희준          성인가요
# 7              권혜경          성인가요
# 8              박재란          성인가요
# 9               현미          성인가요
# 10           Add 4          록/메탈
# 11             남일해          성인가요
# 12             박재란          성인가요
# 13             고봉산          성인가요
# 14              현미          성인가요
# 15             오기택          성인가요
# 16          정 시스터즈          성인가요
# 17             남일해          성인가요
# 18             위키리          성인가요
# 19             최희준          성인가요
# 20             남일해          성인가요
# 21             최양숙          성인가요
# 22             조애희          성인가요
# 23             곽순옥          성인가요
# 24         쟈니 브라더스          성인가요
# 25             남일해          성인가요
# 26          쟈니부라더스          성인가요
# ...

# %%
### second version of data (genre regrouped and dropped links column for display convenience)

# %%
df2 = pd.read_csv('./datas/final2019(rev).csv', index_col=[0])
df2
# Out:
#             Artist       Genre  \
# 0              금호동        성인가요
# 1              최숙자        성인가요
# 2              이미자        성인가요
# 3              이미자        성인가요
# 4               현미        성인가요
# 5              백야성        성인가요
# 6              최희준        성인가요
# 7              권혜경        성인가요
# 8              박재란        성인가요
# 9               현미        성인가요
# 10           Add 4        록/메탈
# 11             남일해        성인가요
# 12             박재란        성인가요
# 13             고봉산        성인가요
# 14              현미        성인가요
# 15             오기택        성인가요
# 16          정 시스터즈        성인가요
# 17             남일해        성인가요
# 18             위키리        성인가요
# 19             최희준        성인가요
# 20             남일해        성인가요
# 21             최양숙        성인가요
# 22             조애희        성인가요
# 23             곽순옥        성인가요
# 24         쟈니 브라더스        성인가요
# 25             남일해        성인가요
# 26          쟈니부라더스        성인가요
# 27             한명숙        성인가요
# 28             박재란        성인가요
# ...

# %%
### third version of dataframe (lyrics data added but something went wrong with the link column)

# %%
df3 = pd.read_csv('./datas/final2019(rev2).csv', index_col=[0])
df3
# Out:
#             Artist         Genre  \
# 0              금호동          성인가요
# 1              최숙자          성인가요
# 2              이미자          성인가요
# 3              이미자          성인가요
# 4               현미          성인가요
# 5              백야성          성인가요
# 6              최희준          성인가요
# 7              권혜경          성인가요
# 8              박재란          성인가요
# 9               현미          성인가요
# 10           Add 4          록/메탈
# 11             남일해          성인가요
# 12             박재란          성인가요
# 13             고봉산          성인가요
# 14              현미          성인가요
# 15             오기택          성인가요
# 16          정 시스터즈          성인가요
# 17             남일해          성인가요
# 18             위키리          성인가요
# 19             최희준          성인가요
# 20             남일해          성인가요
# 21             최양숙          성인가요
# 22             조애희          성인가요
# 23             곽순옥          성인가요
# 24         쟈니 브라더스          성인가요
# 25             남일해          성인가요
# 26          쟈니부라더스          성인가요
# ...

# %%
df4 = pd.read_csv('./datas/final2019(rev3).csv', index_col=[0])
df4
# Out:
#             Artist         Genre  \
# 0              금호동          성인가요
# 1              최숙자          성인가요
# 2              이미자          성인가요
# 3              이미자          성인가요
# 4               현미          성인가요
# 5              백야성          성인가요
# 6              최희준          성인가요
# 7              권혜경          성인가요
# 8              박재란          성인가요
# 9               현미          성인가요
# 10           Add 4          록/메탈
# 11             남일해          성인가요
# 12             박재란          성인가요
# 13             고봉산          성인가요
# 14              현미          성인가요
# 15             오기택          성인가요
# 16          정 시스터즈          성인가요
# 17             남일해          성인가요
# 18             위키리          성인가요
# 19             최희준          성인가요
# 20             남일해          성인가요
# 21             최양숙          성인가요
# 22             조애희          성인가요
# 23             곽순옥          성인가요
# 24         쟈니 브라더스          성인가요
# 25             남일해          성인가요
# 26          쟈니부라더스          성인가요
# ...

# %%
### final version of dataframe (genre regrouped, duplicate rows dropped, lyrics and genre column added completely)

# %%
df5 =  pd.read_csv('./datas/final2019(rev4).csv', index_col=[0])
df5
# Out:
#             Artist       Genre  \
# 0              금호동        성인가요
# 1              최숙자        성인가요
# 2              이미자        성인가요
# 3              이미자        성인가요
# 4               현미        성인가요
# 5              백야성        성인가요
# 6              최희준        성인가요
# 7              권혜경        성인가요
# 8              박재란        성인가요
# 9               현미        성인가요
# 10           Add 4        록/메탈
# 11             남일해        성인가요
# 12             박재란        성인가요
# 13             고봉산        성인가요
# 14              현미        성인가요
# 15             오기택        성인가요
# 16          정 시스터즈        성인가요
# 17             남일해        성인가요
# 18             위키리        성인가요
# 19             최희준        성인가요
# 20             남일해        성인가요
# 21             최양숙        성인가요
# 22             조애희        성인가요
# 23             곽순옥        성인가요
# 24         쟈니 브라더스        성인가요
# 25             남일해        성인가요
# 26          쟈니부라더스        성인가요
# 27             한명숙        성인가요
# 28             박재란        성인가요
# ...

# %%
### pip list to check installed packages and put them in one file 'requirements.txt'

# %%
# !pip list
# Out:
# Package               Version
# --------------------- -------------------
# argon2-cffi           20.1.0
# async-generator       1.10
# attrs                 20.2.0
# backcall              0.2.0
# beautifulsoup4        4.9.3
# bleach                3.2.1
# branca                0.4.1
# bs4                   0.0.1
# certifi               2020.11.8
# cffi                  1.14.3
# chardet               3.0.4
# cmdstanpy             0.9.5
# colorama              0.4.4
# convertdate           2.3.0
# cycler                0.10.0
# Cython                0.29.21
# decorator             4.4.2
# defusedxml            0.6.0
# entrypoints           0.3
# ephem                 3.7.7.1
# fbprophet             0.7.1
# folium                0.11.0
# graphviz              0.14.2
# holidays              0.10.3
# idna                  2.10
# imbalanced-learn      0.7.0
# importlib-metadata    2.0.0
# ipykernel             5.3.4
# ipython               7.18.1
# ipython-genutils      0.2.0
# ...

# %%
# !pip freeze > requirements.txt
